# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website = 'https://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank     Team       Won         Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys          502   374     6   0.573  1960.000    882
# 1     2    Green       Bay      Packers   737   562  37.000     0.565   1921
# 2     3  Chicago     Bears          749   579    42   0.562  1920.000  1,370
# 3     4    Miami  Dolphins          445   351     4   0.559  1966.000    800
# 4     5      New   England  Patriots[b]   489   386   9.000     0.558   1960
#
#    Total  Games Division
# 0    NFC   East      NaN
# 1  1,336    NFC    North
# 2    NFC  North      NaN
# 3    AFC   East      NaN
# 4    884    AFC     East

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First', 'NFL', 'Season',
#        'Total', 'Games', 'Division'],
#       dtype='object')

# %%
nfl_frame['First']
# Out:
# 0     0.573
# 1    37.000
# 2     0.562
# 3     0.559
# 4     9.000
# Name: First, dtype: float64

# %%
DataFrame(nfl_frame, columns = ['Team','Lost','Won','other'])
# Out:
#       Team         Lost       Won  other
# 0   Dallas          502   Cowboys    NaN
# 1    Green      Packers       Bay    NaN
# 2  Chicago          749     Bears    NaN
# 3    Miami          445  Dolphins    NaN
# 4      New  Patriots[b]   England    NaN

# %%
nfl_frame.head(2)
# Out:
#    Rank    Team      Won     Lost  Tied  Pct.   First       NFL Season  Total  \
# 0     1  Dallas  Cowboys      502   374     6   0.573  1960.000    882    NFC
# 1     2   Green      Bay  Packers   737   562  37.000     0.565   1921  1,336
#
#   Games Division
# 0  East      NaN
# 1   NFC    North

# %%
nfl_frame.tail(2)
# Out:
#    Rank   Team       Won         Lost  Tied  Pct.  First       NFL Season  \
# 3     4  Miami  Dolphins          445   351     4  0.559  1966.000    800
# 4     5    New   England  Patriots[b]   489   386  9.000     0.558   1960
#
#   Total Games Division
# 3   AFC  East      NaN
# 4   884   AFC     East

# %%
nfl_frame.ix[3]
# Out:
# Rank               4
# Team           Miami
# Won         Dolphins
# Lost             445
# Tied             351
# Pct.               4
# First          0.559
# NFL             1966
# Season           800
# Total            AFC
# Games           East
# Division         NaN
# Name: 3, dtype: object

# %%
nfl_frame['other'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank     Team       Won         Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys          502   374     6   0.573  1960.000    882
# 1     2    Green       Bay      Packers   737   562  37.000     0.565   1921
# 2     3  Chicago     Bears          749   579    42   0.562  1920.000  1,370
# 3     4    Miami  Dolphins          445   351     4   0.559  1966.000    800
# 4     5      New   England  Patriots[b]   489   386   9.000     0.558   1960
#
#    Total  Games Division           other
# 0    NFC   East      NaN  Levi's Stadium
# 1  1,336    NFC    North  Levi's Stadium
# 2    NFC  North      NaN  Levi's Stadium
# 3    AFC   East      NaN  Levi's Stadium
# 4    884    AFC     East  Levi's Stadium

# %%
nfl_frame['other'] = np.arange(5)

# %%
nfl_frame
# Out:
#    Rank     Team       Won         Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys          502   374     6   0.573  1960.000    882
# 1     2    Green       Bay      Packers   737   562  37.000     0.565   1921
# 2     3  Chicago     Bears          749   579    42   0.562  1920.000  1,370
# 3     4    Miami  Dolphins          445   351     4   0.559  1966.000    800
# 4     5      New   England  Patriots[b]   489   386   9.000     0.558   1960
#
#    Total  Games Division  other
# 0    NFC   East      NaN      0
# 1  1,336    NFC    North      1
# 2    NFC  North      NaN      2
# 3    AFC   East      NaN      3
# 4    884    AFC     East      4

# %%
stadiums = Series(["Levi's Stadium","AT&T Stadium"], index = [4,0])

# %%
nfl_frame['other'] = stadiums

# %%
nfl_frame
# Out:
#    Rank     Team       Won         Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys          502   374     6   0.573  1960.000    882
# 1     2    Green       Bay      Packers   737   562  37.000     0.565   1921
# 2     3  Chicago     Bears          749   579    42   0.562  1920.000  1,370
# 3     4    Miami  Dolphins          445   351     4   0.559  1966.000    800
# 4     5      New   England  Patriots[b]   489   386   9.000     0.558   1960
#
#    Total  Games Division           other
# 0    NFC   East      NaN    AT&T Stadium
# 1  1,336    NFC    North             NaN
# 2    NFC  North      NaN             NaN
# 3    AFC   East      NaN             NaN
# 4    884    AFC     East  Levi's Stadium

# %%
del nfl_frame['other']

# %%
nfl_frame
# Out:
#    Rank     Team       Won         Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys          502   374     6   0.573  1960.000    882
# 1     2    Green       Bay      Packers   737   562  37.000     0.565   1921
# 2     3  Chicago     Bears          749   579    42   0.562  1920.000  1,370
# 3     4    Miami  Dolphins          445   351     4   0.559  1966.000    800
# 4     5      New   England  Patriots[b]   489   386   9.000     0.558   1960
#
#    Total  Games Division
# 0    NFC   East      NaN
# 1  1,336    NFC    North
# 2    NFC  North      NaN
# 3    AFC   East      NaN
# 4    884    AFC     East

# %%
data = {'City': ['SF', 'LA', 'NYC'], 'Population': [8370000,3880000,8400000]}

# %%
city_frame = DataFrame(data)
city_frame
# Out:
#   City  Population
# 0   SF     8370000
# 1   LA     3880000
# 2  NYC     8400000

# %%
city_frame.drop('City',axis=1) #axis = 1 means that drop by column, default axis = 0 means drop by row
# Out:
#    Population
# 0     8370000
# 1     3880000
# 2     8400000

# %%
city_frame[city_frame['Population']>8000000]
# Out:
#   City  Population
# 0   SF     8370000
# 2  NYC     8400000

# %%
city_frame.ix[0]
# Out:
# City               SF
# Population    8370000
# Name: 0, dtype: object

# %%
dframe1 = DataFrame(np.arange(4).reshape((2,2)),columns=list('AB'), index=['NYC', 'LA'])
dframe1
# Out:
#      A  B
# NYC  0  1
# LA   2  3

# %%
dframe2 = DataFrame(np.arange(9).reshape((3,3)),columns=list('ADC'), index=['NYC', 'SF', 'LA'])
dframe2
# Out:
#      A  D  C
# NYC  0  1  2
# SF   3  4  5
# LA   6  7  8

# %%
dframe1 + dframe2
# Out:
#        A   B   C   D
# LA   8.0 NaN NaN NaN
# NYC  0.0 NaN NaN NaN
# SF   NaN NaN NaN NaN

# %%
dframe1.add(dframe2,fill_value=0)
# Out:
#        A    B    C    D
# LA   8.0  3.0  8.0  7.0
# NYC  0.0  1.0  2.0  1.0
# SF   3.0  NaN  5.0  4.0

# %%
ser3 = dframe2.ix[0]
ser3
# Out:
# A    0
# D    1
# C    2
# Name: NYC, dtype: int64

# %%
dframe2 - ser3
# Out:
#      A  D  C
# NYC  0  0  0
# SF   3  3  3
# LA   6  6  6

# %%
from numpy.random import randn

# %%
ser2 = Series(randn(10))
ser2
# Out:
# 0   -0.100847
# 1    0.264578
# 2    0.696843
# 3    0.614293
# 4   -0.761680
# 5   -0.921149
# 6   -0.580858
# 7    0.014910
# 8   -0.474451
# 9    0.016352
# dtype: float64
